# %% [markdown]
# <a href="https://colab.research.google.com/github/SadiHassan/NN_From_Scratch/blob/main/NN_From_Scratch00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my attempt of understanding Neural Network from scratch and developing a simple model from scratch.
# I am taking help from multiple youtube videos as I go through. Once (hopefully!) I complete this project, I will give all the links I used to learn this in the resources section.
# Hopefully, you will enjoy this notebook!
#
# # Theoretical Background
# In this part of text, I will try to add all the knowledge I learnt along the way to understand Neural Networks from scratch. Below are the secions I planned to fill up.
#
# ## Neural Network
#
#
# ## Input Layer
#
#
# ## Hidden Layer
#
#
# ## Output Layer
#
#
# ## Weights and Biases, why?
#
#
# ## Activation functions - ReLu, tanh, Softmax
#
#
# ## Forward Propagation
#
#
# ## Backward Propagation
#
#
# ## MNIST Dataset, Data Structure, Input Output Representation etc.
#
#
# ## Coding Steps
#
#
# ## Resources

# %%
print("Hello World!")
# Out:
# Hello World!
